# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import os
import sys
from PIL import Image

# %% [markdown]
# ## Load data

# %%
masks = glob.glob("../input/t500_train_res_400x400/*.png")
orgs = list(map(lambda x: x.replace(".png", ".jpg"), masks))

# %%
imgs_list = []
masks_list = []
for image, mask in zip(orgs, masks):
    imgs_list.append(np.array(Image.open(image).resize((384,384))))
    masks_list.append(np.array(Image.open(mask).resize((384,384))))

imgs_np = np.asarray(imgs_list)
masks_np = np.asarray(masks_list)

# %%
print(imgs_np.shape, masks_np.shape)
# Out:
# (148, 384, 384, 3) (148, 384, 384)

# %% [markdown]
# ## Plot images + masks + overlay (mask over original)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=imgs_np, mask_imgs=masks_np, img_size=384, nm_img_to_plot=10, figsize=6)

# %% [markdown]
# ## Get data into correct shape, dtype and range (0.0-1.0)

# %%
print(imgs_np.max(), masks_np.max())
# Out:
# 255 1

# %%
x = np.asarray(imgs_np, dtype=np.float32)/255
y = np.asarray(masks_np, dtype=np.float32)

# %%
print(x.max(), y.max())
# Out:
# 1.0 1.0

# %%
print(x.shape, y.shape)
# Out:
# (148, 384, 384, 3) (148, 384, 384)

# %%
y = y.reshape(y.shape[0], y.shape[1], y.shape[2], 1)
print(x.shape, y.shape)
# Out:
# (148, 384, 384, 3) (148, 384, 384, 1)

# %% [markdown]
# ##  Train/val split

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.3, random_state=0)

print("x_train: ", x_train.shape)
print("y_train: ", y_train.shape)
print("x_val: ", x_val.shape)
print("y_val: ", y_val.shape)
# Out:
# x_train:  (103, 384, 384, 3)
# y_train:  (103, 384, 384, 1)
# x_val:  (45, 384, 384, 3)
# y_val:  (45, 384, 384, 1)

# %% [markdown]
# ## Prepare train generator with data augmentation

# %%
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    x_train, y_train, batch_size=2,
    data_gen_args = dict(
        rotation_range=5.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=40,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode='constant'
    ))

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy, img_size=384, nm_img_to_plot=2, figsize=6)
# Out:
# (2, 384, 384, 3) (2, 384, 384, 1)

# %% [markdown]
# ## Initialize network

# %%
from keras_unet.models import unet, unet_satellite

input_shape = x_train[0].shape

model = unet.unet(
    input_shape,
    filters=64,
    use_batch_norm=True,
    dropout=0.4,
    dropout_change_per_layer=0.0,
    num_layers=4
)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 384, 384, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 384, 384, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 384, 384, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 384, 384, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 384, 384, 64) 36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 384, 384, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 192, 192, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 192, 192, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 192, 192, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 192, 192, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 192, 192, 128 147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 192, 192, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 96, 96, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 96, 96, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 96, 96, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 96, 96, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 96, 96, 256)  590080      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 96, 96, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 48, 48, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 48, 48, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 48, 48, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 48, 48, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 48, 48, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 48, 48, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 24, 24, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 24, 24, 1024) 4719616     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 24, 24, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 24, 24, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 24, 24, 1024) 9438208     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 24, 24, 1024) 4096        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 48, 48, 512)  2097664     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 48, 1024) 0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 48, 48, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 48, 48, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 48, 48, 512)  2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 48, 48, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 96, 96, 256)  524544      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 96, 96, 512)  0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 96, 96, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 96, 96, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 96, 96, 256)  590080      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 96, 96, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 192, 192, 128 131200      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 192, 192, 256 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 192, 192, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 192, 192, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 192, 192, 128 147584      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 192, 192, 128 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 384, 384, 64) 32832       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 384, 384, 128 0           conv2d_transpose_4[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 384, 384, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 384, 384, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 384, 384, 64) 36928       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 384, 384, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 384, 384, 1)  65          batch_normalization_18[0][0]
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile + train

# %%
from keras.callbacks import ModelCheckpoint


model_filename = 'segm_model_v3.h5'
callback_checkpoint = ModelCheckpoint(
    model_filename, 
    verbose=1, 
    monitor='val_loss', 
    save_best_only=True,
)

# %%
from keras.optimizers import Adam, SGD
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance

model.compile(
    optimizer=Adam(), 
    #optimizer=SGD(lr=0.01, momentum=0.99),
    #loss='binary_crossentropy',
    loss=jaccard_distance,
    metrics=[iou, iou_thresholded]
)

# %%
history = model.fit_generator(
    train_gen,
    steps_per_epoch=100,
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=[callback_checkpoint]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.1795 - iou: 0.3924 - iou_thresholded: 0.4244 - val_loss: 0.3580 - val_iou: 0.3125 - val_iou_thresholded: 0.3131
#
# Epoch 00001: val_loss improved from inf to 0.35800, saving model to segm_model_v3.h5
# Epoch 2/100
# 100/100 [==============================] - 53s 533ms/step - loss: 0.1019 - iou: 0.4989 - iou_thresholded: 0.5125 - val_loss: 0.3336 - val_iou: 0.3333 - val_iou_thresholded: 0.3335
#
# Epoch 00002: val_loss improved from 0.35800 to 0.33364, saving model to segm_model_v3.h5
# Epoch 3/100
#  26/100 [======>.......................] - ETA: 37s - loss: 0.0780 - iou: 0.5753 - iou_thresholded: 0.5843

# %% [markdown]
# ## Plot training history

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %% [markdown]
# ## Plot original + ground truth + pred + overlay (pred on top of original)

# %%
model.load_weights(model_filename)
y_pred = model.predict(x_val)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=x_val, mask_imgs=y_val, pred_imgs=y_pred, img_size=384, nm_img_to_plot=10)
