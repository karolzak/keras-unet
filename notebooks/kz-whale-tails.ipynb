# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import os
import sys
from PIL import Image

# %% [markdown]
# ## Load data

# %%
masks = glob.glob("../input/t500_train_res_400x400/*.png")
orgs = list(map(lambda x: x.replace(".png", ".jpg"), masks))

# %%
imgs_list = []
masks_list = []
for image, mask in zip(orgs, masks):
    imgs_list.append(np.array(Image.open(image).resize((384,384))))
    masks_list.append(np.array(Image.open(mask).resize((384,384))))

imgs_np = np.asarray(imgs_list)
masks_np = np.asarray(masks_list)

# %%
print(imgs_np.shape, masks_np.shape)

# %% [markdown]
# ## Plot images + masks + overlay (mask over original)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=imgs_np, mask_imgs=masks_np, img_size=384, nm_img_to_plot=10, figsize=6)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Get data into correct shape, dtype and range (0.0-1.0)

# %%
print(imgs_np.max(), masks_np.max())
# Out:
# 255 1

# %%
x = np.asarray(imgs_np, dtype=np.float32)/255
y = np.asarray(masks_np, dtype=np.float32)

# %%
print(x.max(), y.max())
# Out:
# 1.0 1.0

# %%
print(x.shape, y.shape)
# Out:
# (148, 384, 384, 3) (148, 384, 384)

# %%
y = y.reshape(y.shape[0], y.shape[1], y.shape[2], 1)
print(x.shape, y.shape)
# Out:
# (148, 384, 384, 3) (148, 384, 384, 1)

# %% [markdown]
# ##  Train/val split

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.9, random_state=0)

print("x_train: ", x_train.shape)
print("y_train: ", y_train.shape)
print("x_val: ", x_val.shape)
print("y_val: ", y_val.shape)
# Out:
# x_train:  (14, 384, 384, 3)
# y_train:  (14, 384, 384, 1)
# x_val:  (134, 384, 384, 3)
# y_val:  (134, 384, 384, 1)

# %% [markdown]
# ## Prepare train generator with data augmentation

# %%
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    x_train, y_train, batch_size=2,
    data_gen_args = dict(
        rotation_range=5.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=40,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode='constant'
    ))

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy, img_size=384, nm_img_to_plot=2, figsize=6)
# Out:
# (2, 384, 384, 3) (2, 384, 384, 1)

# %% [markdown]
# ## Initialize network

# %%
from keras_unet.models import unet, unet_satellite

input_shape = x_train[0].shape

model = unet.unet(
    input_shape,
    filters=32,
    use_batch_norm=True,
    dropout=0.3,
    dropout_change_per_layer=0.0,
    num_layers=4
)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 384, 384, 3)  0
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 384, 384, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 384, 384, 32) 128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 384, 384, 32) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 384, 384, 32) 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 384, 384, 32) 128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 192, 192, 32) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 192, 192, 64) 18496       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 192, 192, 64) 256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 192, 192, 64) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 192, 192, 64) 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 192, 192, 64) 256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 96, 96, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 96, 96, 128)  73856       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 96, 96, 128)  512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 96, 96, 128)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 96, 96, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 96, 96, 128)  512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 48, 48, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 48, 48, 256)  295168      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 48, 48, 256)  1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 48, 48, 256)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 48, 48, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 48, 48, 256)  1024        conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 24, 24, 256)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 24, 24, 512)  1180160     max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 24, 24, 512)  2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 24, 24, 512)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 24, 24, 512)  2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 24, 24, 512)  2048        conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 48, 48, 256)  524544      batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 48, 48, 512)  0           conv2d_transpose_9[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 48, 48, 256)  1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 48, 48, 256)  1024        conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 48, 48, 256)  590080      batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 48, 48, 256)  1024        conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 96, 96, 128)  131200      batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 96, 96, 256)  0           conv2d_transpose_10[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 96, 96, 128)  295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 96, 96, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 96, 96, 128)  147584      batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 96, 96, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 192, 192, 64) 32832       batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 192, 192, 128 0           conv2d_transpose_11[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 192, 192, 64) 73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 192, 192, 64) 256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 192, 192, 64) 36928       batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 192, 192, 64) 256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 384, 384, 32) 8224        batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 384, 384, 64) 0           conv2d_transpose_12[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 384, 384, 32) 18464       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 384, 384, 32) 128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 384, 384, 32) 9248        batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 384, 384, 32) 128         conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 384, 384, 1)  33          batch_normalization_54[0][0]
# ==================================================================================================
# Total params: 7,771,873
# Trainable params: 7,765,985
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile + train

# %%
from keras.callbacks import ModelCheckpoint


model_filename = 'segm_model_v3.h5'
callback_checkpoint = ModelCheckpoint(
    model_filename, 
    verbose=1, 
    monitor='val_loss', 
    save_best_only=True,
)

# %%
from keras.optimizers import Adam, SGD
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance

model.compile(
    #optimizer=Adam(), 
    optimizer=SGD(lr=0.01, momentum=0.99),
    loss='binary_crossentropy',
    #loss=jaccard_distance,
    metrics=[iou, iou_thresholded]
)

# %%
history = model.fit_generator(
    train_gen,
    steps_per_epoch=200,
    epochs=40,
    
    validation_data=(x_val, y_val),
    callbacks=[callback_checkpoint]
)
# Out:
# Epoch 1/40
# 200/200 [==============================] - 45s 226ms/step - loss: 0.2786 - iou: 0.3909 - iou_thresholded: 0.4612 - val_loss: 2.8481 - val_iou: 0.3940 - val_iou_thresholded: 0.3936
#
# Epoch 00001: val_loss improved from inf to 2.84814, saving model to segm_model_v3.h5
# Epoch 2/40
# 200/200 [==============================] - 51s 254ms/step - loss: 0.1635 - iou: 0.5697 - iou_thresholded: 0.6620 - val_loss: 3.1075 - val_iou: 0.3430 - val_iou_thresholded: 0.3420
#
# Epoch 00002: val_loss did not improve from 2.84814
# Epoch 3/40
# 200/200 [==============================] - 53s 267ms/step - loss: 0.1153 - iou: 0.6885 - iou_thresholded: 0.7726 - val_loss: 0.3907 - val_iou: 0.4624 - val_iou_thresholded: 0.5428
#
# Epoch 00003: val_loss improved from 2.84814 to 0.39072, saving model to segm_model_v3.h5
# Epoch 4/40
# 200/200 [==============================] - 60s 302ms/step - loss: 0.0858 - iou: 0.7581 - iou_thresholded: 0.8284 - val_loss: 0.6798 - val_iou: 0.3908 - val_iou_thresholded: 0.4899
#
# Epoch 00004: val_loss did not improve from 0.39072
# Epoch 5/40
# 200/200 [==============================] - 61s 307ms/step - loss: 0.0678 - iou: 0.8029 - iou_thresholded: 0.8629 - val_loss: 0.3383 - val_iou: 0.5586 - val_iou_thresholded: 0.5734
#
# Epoch 00005: val_loss improved from 0.39072 to 0.33828, saving model to segm_model_v3.h5
# Epoch 6/40
# 200/200 [==============================] - 66s 328ms/step - loss: 0.0477 - iou: 0.8556 - iou_thresholded: 0.8986 - val_loss: 0.3895 - val_iou: 0.5942 - val_iou_thresholded: 0.6187
#
# Epoch 00006: val_loss did not improve from 0.33828
# Epoch 7/40
# 200/200 [==============================] - 64s 318ms/step - loss: 0.0373 - iou: 0.8854 - iou_thresholded: 0.9189 - val_loss: 0.2664 - val_iou: 0.6515 - val_iou_thresholded: 0.6793
#
# Epoch 00007: val_loss improved from 0.33828 to 0.26639, saving model to segm_model_v3.h5
# Epoch 8/40
# 200/200 [==============================] - 73s 363ms/step - loss: 0.0478 - iou: 0.8631 - iou_thresholded: 0.9003 - val_loss: 0.2530 - val_iou: 0.6609 - val_iou_thresholded: 0.6908
#
# Epoch 00008: val_loss improved from 0.26639 to 0.25304, saving model to segm_model_v3.h5
# Epoch 9/40
# 200/200 [==============================] - 64s 319ms/step - loss: 0.0342 - iou: 0.8930 - iou_thresholded: 0.9252 - val_loss: 0.2943 - val_iou: 0.6533 - val_iou_thresholded: 0.6702
#
# Epoch 00009: val_loss did not improve from 0.25304
# Epoch 10/40
# 200/200 [==============================] - 77s 384ms/step - loss: 0.0268 - iou: 0.9156 - iou_thresholded: 0.9405 - val_loss: 0.2177 - val_iou: 0.7053 - val_iou_thresholded: 0.7264
#
# Epoch 00010: val_loss improved from 0.25304 to 0.21766, saving model to segm_model_v3.h5
# Epoch 11/40
# 200/200 [==============================] - 66s 329ms/step - loss: 0.0229 - iou: 0.9263 - iou_thresholded: 0.9481 - val_loss: 0.2415 - val_iou: 0.7049 - val_iou_thresholded: 0.7222
#
# Epoch 00011: val_loss did not improve from 0.21766
# Epoch 12/40
# 200/200 [==============================] - 71s 353ms/step - loss: 0.0208 - iou: 0.9339 - iou_thresholded: 0.9529 - val_loss: 0.3580 - val_iou: 0.6707 - val_iou_thresholded: 0.6812
#
# Epoch 00012: val_loss did not improve from 0.21766
# Epoch 13/40
# 200/200 [==============================] - 73s 363ms/step - loss: 0.0207 - iou: 0.9338 - iou_thresholded: 0.9529 - val_loss: 0.3055 - val_iou: 0.6919 - val_iou_thresholded: 0.7081
#
# Epoch 00013: val_loss did not improve from 0.21766
# Epoch 14/40
# 200/200 [==============================] - 72s 360ms/step - loss: 0.0188 - iou: 0.9396 - iou_thresholded: 0.9571 - val_loss: 0.3536 - val_iou: 0.6843 - val_iou_thresholded: 0.6954
#
# Epoch 00014: val_loss did not improve from 0.21766
# Epoch 15/40
# 200/200 [==============================] - 80s 398ms/step - loss: 0.0173 - iou: 0.9433 - iou_thresholded: 0.9602 - val_loss: 0.3196 - val_iou: 0.7111 - val_iou_thresholded: 0.7218
#
# Epoch 00015: val_loss did not improve from 0.21766
# Epoch 16/40
# 200/200 [==============================] - 71s 356ms/step - loss: 0.0173 - iou: 0.9445 - iou_thresholded: 0.9601 - val_loss: 0.3228 - val_iou: 0.7036 - val_iou_thresholded: 0.7163
#
# Epoch 00016: val_loss did not improve from 0.21766
# Epoch 17/40
# 200/200 [==============================] - 70s 351ms/step - loss: 0.0156 - iou: 0.9478 - iou_thresholded: 0.9631 - val_loss: 0.3266 - val_iou: 0.7185 - val_iou_thresholded: 0.7309
#
# Epoch 00017: val_loss did not improve from 0.21766
# Epoch 18/40
# 200/200 [==============================] - 84s 422ms/step - loss: 0.0144 - iou: 0.9525 - iou_thresholded: 0.9665 - val_loss: 0.3206 - val_iou: 0.7153 - val_iou_thresholded: 0.7258
#
# Epoch 00018: val_loss did not improve from 0.21766
# Epoch 19/40
# 200/200 [==============================] - 69s 347ms/step - loss: 0.0142 - iou: 0.9535 - iou_thresholded: 0.9671 - val_loss: 0.3695 - val_iou: 0.6988 - val_iou_thresholded: 0.7072
#
# Epoch 00019: val_loss did not improve from 0.21766
# Epoch 20/40
# 200/200 [==============================] - 72s 360ms/step - loss: 0.0128 - iou: 0.9569 - iou_thresholded: 0.9695 - val_loss: 0.3958 - val_iou: 0.6992 - val_iou_thresholded: 0.7069
#
# Epoch 00020: val_loss did not improve from 0.21766
# Epoch 21/40
# 200/200 [==============================] - 72s 361ms/step - loss: 0.0129 - iou: 0.9579 - iou_thresholded: 0.9701 - val_loss: 0.3459 - val_iou: 0.7184 - val_iou_thresholded: 0.7273
#
# Epoch 00021: val_loss did not improve from 0.21766
# Epoch 22/40
# 200/200 [==============================] - 66s 332ms/step - loss: 0.0127 - iou: 0.9569 - iou_thresholded: 0.9696 - val_loss: 0.3509 - val_iou: 0.7211 - val_iou_thresholded: 0.7293
#
# Epoch 00022: val_loss did not improve from 0.21766
# Epoch 23/40
# 200/200 [==============================] - 76s 379ms/step - loss: 0.0122 - iou: 0.9589 - iou_thresholded: 0.9708 - val_loss: 0.3863 - val_iou: 0.7053 - val_iou_thresholded: 0.7133
#
# Epoch 00023: val_loss did not improve from 0.21766
# Epoch 24/40
# 200/200 [==============================] - 67s 334ms/step - loss: 0.0116 - iou: 0.9604 - iou_thresholded: 0.9722 - val_loss: 0.3886 - val_iou: 0.7140 - val_iou_thresholded: 0.7210
#
# Epoch 00024: val_loss did not improve from 0.21766
# Epoch 25/40
# 200/200 [==============================] - 73s 367ms/step - loss: 0.0127 - iou: 0.9580 - iou_thresholded: 0.9701 - val_loss: 0.4167 - val_iou: 0.6952 - val_iou_thresholded: 0.7033
#
# Epoch 00025: val_loss did not improve from 0.21766
# Epoch 26/40
# 200/200 [==============================] - 70s 350ms/step - loss: 0.0117 - iou: 0.9605 - iou_thresholded: 0.9719 - val_loss: 0.4145 - val_iou: 0.6973 - val_iou_thresholded: 0.7050
#
# Epoch 00026: val_loss did not improve from 0.21766
# Epoch 27/40
# 200/200 [==============================] - 70s 348ms/step - loss: 0.0115 - iou: 0.9615 - iou_thresholded: 0.9725 - val_loss: 0.4604 - val_iou: 0.6974 - val_iou_thresholded: 0.7045
#
# Epoch 00027: val_loss did not improve from 0.21766
# Epoch 28/40
# 200/200 [==============================] - 77s 384ms/step - loss: 0.0116 - iou: 0.9614 - iou_thresholded: 0.9728 - val_loss: 0.3509 - val_iou: 0.7235 - val_iou_thresholded: 0.7307
#
# Epoch 00028: val_loss did not improve from 0.21766
# Epoch 29/40
# 200/200 [==============================] - 66s 331ms/step - loss: 0.0109 - iou: 0.9634 - iou_thresholded: 0.9743 - val_loss: 0.3709 - val_iou: 0.7208 - val_iou_thresholded: 0.7279
#
# Epoch 00029: val_loss did not improve from 0.21766
# Epoch 30/40
# 200/200 [==============================] - 76s 381ms/step - loss: 0.0110 - iou: 0.9638 - iou_thresholded: 0.9742 - val_loss: 0.4249 - val_iou: 0.6994 - val_iou_thresholded: 0.7061
#
# Epoch 00030: val_loss did not improve from 0.21766
# Epoch 31/40
# 200/200 [==============================] - 74s 368ms/step - loss: 0.0106 - iou: 0.9639 - iou_thresholded: 0.9747 - val_loss: 0.4022 - val_iou: 0.7168 - val_iou_thresholded: 0.7236
#
# Epoch 00031: val_loss did not improve from 0.21766
# Epoch 32/40
# 200/200 [==============================] - 71s 354ms/step - loss: 0.0111 - iou: 0.9631 - iou_thresholded: 0.9734 - val_loss: 0.4615 - val_iou: 0.7069 - val_iou_thresholded: 0.7136
#
# Epoch 00032: val_loss did not improve from 0.21766
# Epoch 33/40
# 200/200 [==============================] - 77s 385ms/step - loss: 0.0103 - iou: 0.9644 - iou_thresholded: 0.9748 - val_loss: 0.3855 - val_iou: 0.7242 - val_iou_thresholded: 0.7310
# Epoch 00033: val_loss did not improve from 0.21766
# Epoch 34/40
# 200/200 [==============================] - 68s 338ms/step - loss: 0.0100 - iou: 0.9660 - iou_thresholded: 0.9760 - val_loss: 0.3727 - val_iou: 0.7230 - val_iou_thresholded: 0.7296
#
# Epoch 00034: val_loss did not improve from 0.21766
# Epoch 35/40
# 200/200 [==============================] - 77s 383ms/step - loss: 0.0099 - iou: 0.9660 - iou_thresholded: 0.9756 - val_loss: 0.4284 - val_iou: 0.7134 - val_iou_thresholded: 0.7194
#
# Epoch 00035: val_loss did not improve from 0.21766
# Epoch 36/40
# 200/200 [==============================] - 77s 385ms/step - loss: 0.0099 - iou: 0.9663 - iou_thresholded: 0.9761 - val_loss: 0.4025 - val_iou: 0.7112 - val_iou_thresholded: 0.7170
#
# Epoch 00036: val_loss did not improve from 0.21766
# Epoch 37/40
# 200/200 [==============================] - 71s 354ms/step - loss: 0.0097 - iou: 0.9667 - iou_thresholded: 0.9765 - val_loss: 0.4465 - val_iou: 0.7024 - val_iou_thresholded: 0.7082
#
# Epoch 00037: val_loss did not improve from 0.21766
# Epoch 38/40
# 200/200 [==============================] - 79s 397ms/step - loss: 0.0095 - iou: 0.9682 - iou_thresholded: 0.9772 - val_loss: 0.4386 - val_iou: 0.7076 - val_iou_thresholded: 0.7133
#
# Epoch 00038: val_loss did not improve from 0.21766
# Epoch 39/40
# 200/200 [==============================] - 71s 353ms/step - loss: 0.0095 - iou: 0.9680 - iou_thresholded: 0.9773 - val_loss: 0.3971 - val_iou: 0.7189 - val_iou_thresholded: 0.7246
#
# Epoch 00039: val_loss did not improve from 0.21766
# Epoch 40/40
# 200/200 [==============================] - 69s 346ms/step - loss: 0.0091 - iou: 0.9690 - iou_thresholded: 0.9780 - val_loss: 0.4375 - val_iou: 0.7134 - val_iou_thresholded: 0.7189
#
# Epoch 00040: val_loss did not improve from 0.21766

# %% [markdown]
# ## Plot training history

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %% [markdown]
# ## Plot original + ground truth + pred + overlay (pred on top of original)

# %%
model.load_weights(model_filename)
y_pred = model.predict(x_val)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=x_val, mask_imgs=y_val, pred_imgs=y_pred, img_size=384, nm_img_to_plot=10)
